# %% [markdown]
# # Coleta de dados estruturados em lista de arquivos
#
# Nesse exercício prático, vamos coletar os dados através de vários arquivos separados por data. O dataset utilizados é um conjunto  de dados fictícios que ilustra vendas de veículos nos 3 últimos meses.
#
# Abaixo temos uma amostra de arquivos que contém dados de vendas de veículos por datas.

# %%
import pandas as pd
import os

# %% [markdown]
# Vamos atribuir a uma variável o caminho no qual está armazenados os aquivos que vamos utilizar.

# %%
DIRETORIO = 'C:\\Users\\Breno\\Documents\\ESTUDO PROGRAMAÇÃO\\IGTI\\Projetos\\coleta_dados_estruturados\\Modulo II\\'

# %% [markdown]
# Agora vamos criar uma lista com todos os arquivos que estão armazenados no diretório.
#
# O método listdir retorna uma lista contendo os nomes das entradas no diretório por path.

# %%
lista_df =[] # cria uma lista
lista_path = os.listdir(DIRETORIO)

# %%
lista_path[:]
# Out:
# ['2020-01-01.csv',
#  '2020-01-02.csv',
#  '2020-01-03.csv',
#  '2020-01-04.csv',
#  '2020-01-05.csv',
#  '2020-01-06.csv',
#  '2020-01-07.csv',
#  '2020-01-08.csv',
#  '2020-01-09.csv',
#  '2020-01-10.csv',
#  '2020-01-11.csv',
#  '2020-01-12.csv',
#  '2020-01-13.csv',
#  '2020-01-14.csv',
#  '2020-01-15.csv',
#  '2020-01-16.csv',
#  '2020-01-17.csv',
#  '2020-01-18.csv',
#  '2020-01-19.csv',
#  '2020-01-20.csv',
#  '2020-01-21.csv',
#  '2020-01-22.csv',
#  '2020-01-23.csv',
#  '2020-01-24.csv',
#  '2020-01-25.csv',
#  '2020-01-26.csv',
#  '2020-01-27.csv',
#  '2020-01-28.csv',
#  '2020-01-29.csv',
#  '2020-01-30.csv',
#  '2020-01-31.csv',
#  '2020-02-01.csv',
#  '2020-02-02.csv',
#  '2020-02-03.csv',
#  '2020-02-04.csv',
#  '2020-02-05.csv',
#  '2020-02-06.csv',
#  '2020-02-07.csv',
#  '2020-02-08.csv',
#  '2020-02-09.csv',
#  '2020-02-10.csv',
#  '2020-02-11.csv',
#  '2020-02-12.csv',
#  '2020-02-13.csv',
#  '2020-02-14.csv',
#  '2020-02-15.csv',
#  '2020-02-16.csv',
# ...

# %% [markdown]
# Agora temos todos os nomes dos arquivos que estão dentro do diretório. Vamos abrir cada arquivo e coletar seus dados.

# %%
lista_df = [] #cria uma lista vazia

for arquivo in lista_path:
    local_arquivo = os.path.join(DIRETORIO, arquivo)
    df = pd.read_csv(local_arquivo, sep="|", encoding='latin-1')
    lista_df.append(df)
    
df_vendas = pd.concat(lista_df) #Atribui os dados coletados em um dataframe

# %%
df_vendas[:10]
# Out:
#    cod_pessoa data_coleta     genero data_nascimento animal_estimacao  \
# 0    10141743  2020-01-01  Masculino      1981-04-25            peixe
# 1    10141860  2020-01-01   Feminino      1966-01-19            peixe
# 2    10142548  2020-01-01  Masculino      1973-08-02        tartaruga
# 3    10142591  2020-01-01  Masculino      1997-03-05             gato
# 4    10142654  2020-01-01   Feminino      1969-08-05        tartaruga
# 0    10141523  2020-01-02   Feminino      1998-09-24             gato
# 1    10141996  2020-01-02   Feminino      1973-03-13        tartaruga
# 2    10142089  2020-01-02   Feminino      1970-03-23             gato
# 3    10142145  2020-01-02  Masculino      1998-08-01            peixe
# 4    10142520  2020-01-02  Masculino      1994-05-09            peixe
#
#       clima bebida_favorita             hobbies
# 0      frio         Cerveja    Praticar esporte
# 1    quente            Café         Assistir TV
# 2      frio            Café          Ler livros
# ...

# %% [markdown]
# # Exportando dados para arquivos
#
# Agora que ja temos todos os arquivos do diretório, vamos exporta-los apenas um arquivo único.

# %%
df_vendas.to_csv(DIRETORIO + 'vendas_por_data.csv', sep=';', encoding='latin-1', index=False)
